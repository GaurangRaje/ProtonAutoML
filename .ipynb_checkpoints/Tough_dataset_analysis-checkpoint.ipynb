# %% [markdown]
# # Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno
# %matplotlib inline

# %% [markdown]
# # Importing the Dataset

# %%
dataset = pd.read_csv('tough_dataset.csv', encoding = "ISO-8859-1")

# %% [markdown]
# # Exploratory Data Analysis

# %%
pd.set_option('max_columns', None)
dataset.head(15)
# Out:
#           id  Target A  Target B  LOAN_AMT  \
# 0   68407277  42405.00         0      3600
# 1   68355089  60740.00         1     24700
# 2   68341763  51907.68         0     20000
# 3   66310712  51907.68         0     35000
# 4   68476807     35.00         1     10400
# 5   68426831     35.00         0     11950
# 6   68476668  50598.00         0     20000
# 7   67275481  50623.00         1     20000
# 8   68466926  90000.00         0     10000
# 9   68616873  30683.00         0      8000
# 10  68356421  49492.00         0     22400
# 11  68426545  87203.00         0     16000
# 12  68338832  87203.00         0      1400
# 13  66624733      8.75         0     18000
# 14  68466961      8.75         0     28000
#
#                                        Business Title  \
# 0                                     Account Manager
# 1            EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# 2   Maintenance Worker - Technical Services-Heatin...
# ...

# %%
len(dataset)
# Out:
# 2946

# %%
dataset.describe()
# Out:
#                  id       Target A     Target B      LOAN_AMT          dti  \
# count  2.946000e+03    2946.000000  2946.000000   2946.000000  2946.000000
# mean   6.830623e+07   58904.139794     0.210115  15345.663612    19.444117
# std    1.814269e+06   26986.575936     0.407460   8636.391303     8.628543
# min    3.617740e+05       0.000000     0.000000   1000.000000     0.000000
# 25%    6.837622e+07   49390.000000     0.000000   8681.250000    13.035000
# 50%    6.846507e+07   58440.000000     0.000000  14400.000000    18.905000
# 75%    6.853764e+07   73171.750000     0.000000  20000.000000    25.580000
# max    6.861706e+07  218587.000000     1.000000  35000.000000    51.200000
#
#        last_pymnt_amnt
# count      2946.000000
# mean       4663.227026
# std        6855.297610
# min           0.030000
# 25%         362.980000
# 50%         842.235000
# 75%        6832.185000
# max       35467.750000

# %%
dataset.dtypes
# Out:
# id                      int64
# Target A              float64
# Target B                int64
# LOAN_AMT                int64
# Business Title         object
#                        ...
# earliest_cr_line       object
# last_pymnt_d           object
# last_pymnt_amnt       float64
# next_pymnt_d           object
# last_credit_pull_d     object
# Length: 69, dtype: object

# %% [markdown]
# ## Missing Values

# %%
sns.heatmap(dataset.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
missingno.matrix(dataset, figsize = (30,10))
# Out:
# <AxesSubplot:>

# %%
dataset.isnull().sum()
# Out:
# id                       0
# Target A                 0
# Target B                 0
# LOAN_AMT                 0
# Business Title           0
#                       ...
# earliest_cr_line         0
# last_pymnt_d             0
# last_pymnt_amnt          0
# next_pymnt_d          2610
# last_credit_pull_d       0
# Length: 69, dtype: int64

# %% [markdown]
# # Taking care of missing values
# ## Dropping columns with too many missing values(Threshold = 25% missing values)

# %%
df_temp = pd.DataFrame()
for column in dataset:
    missing = dataset.isnull().sum()[column]
    missing_percentage = missing/len(dataset)
    if missing_percentage < 0.25:
        df_temp[column] = dataset[column]

# %%
missingno.matrix(df_temp, figsize = (30,10))
# Out:
# <AxesSubplot:>

# %%
len(df_temp.columns)
# Out:
# 44

# %% [markdown]
# ## Exploring each feature individually

# %%
pd.set_option('max_columns', None)
df_temp.head()
# Out:
#          id  Target A  Target B  LOAN_AMT  \
# 0  68407277  42405.00         0      3600
# 1  68355089  60740.00         1     24700
# 2  68341763  51907.68         0     20000
# 3  66310712  51907.68         0     35000
# 4  68476807     35.00         1     10400
#
#                                       Business Title  \
# 0                                    Account Manager
# 1           EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# 2  Maintenance Worker - Technical Services-Heatin...
# 3  Maintenance Worker - Technical Services-Heatin...
# 4                                  Temporary Painter
#
#               Civil Service Title              Division/Work Unit  \
# 0  CONTRACT REVIEWER (OFFICE OF L            Strategy & Analytics
# 1  ADMINISTRATIVE BUSINESS PROMOT            Tech Talent Pipeline
# 2              MAINTENANCE WORKER  Management Services Department
# 3              MAINTENANCE WORKER  Management Services Department
# ...

# %%
df = pd.DataFrame()

# %% [markdown]
# ### Target feature 1: Target A

# %%
df_temp.isnull().sum()['Target A']
# Out:
# 0

# %%
dataset['Target A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Target A'] = dataset['Target A']

# %% [markdown]
# ### Target variable 2: Target B
# will need to be balanced

# %%
fig = plt.figure(figsize=(20,1))
sns.countplot(y='Target B', data=dataset);
print(dataset['Target B'].value_counts())
# Out:
# 0    2327
# 1     619
# Name: Target B, dtype: int64

# %%
print(f"0: {2327/len(dataset) * 100}% \n1: {619/len(dataset) * 100}%")
# Out:
# 0: 78.98845892735913%
# 1: 21.011541072640867%

# %%
dataset.isnull().sum()['Target B']
# Out:
# 0

# %%
df['Target B'] = dataset['Target B']

# %% [markdown]
# ### LOAN_AMT
# will require feature scaling later

# %%
dataset.isnull().sum()['LOAN_AMT']
# Out:
# 0

# %%
dataset['LOAN_AMT'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['LOAN_AMT'] = dataset['LOAN_AMT']

# %% [markdown]
# ### Business Title

# %%
dataset.isnull().sum()['Business Title']
# Out:
# 0

# %%
len(dataset['Business Title'].unique())
# Out:
# 1244

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

labels = dataset.columns[3:]

X = dataset[labels]
y = dataset['Target B']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

model = XGBClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# /Users/gaurang/.pyenv/versions/3.7.3/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Users/gaurang/.pyenv/versions/3.7.3/lib/python3.7/site-packages/IPython/core/interactiveshell.py, in run_code:
# Line 3437:  exec(code_obj, self.user_global_ns, self.user_ns)
#
# In  [6]:
# Line 13:    model.fit(X_train, y_train)
#
# File /Users/gaurang/.pyenv/versions/3.7.3/lib/python3.7/site-packages/xgboost/core.py, in inner_f:
# ...
